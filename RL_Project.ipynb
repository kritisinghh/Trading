# %% [markdown]
# <a href="https://colab.research.google.com/github/kritisinghh/Trading/blob/main/RL_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this in a NEW Colab notebook cell.
from google.colab import drive
import os, time
from pathlib import Path
import nbformat

# 1) remount Drive
drive.mount('/content/drive', force_remount=True)

# 2) walk MyDrive and find all .ipynb files
root = Path('/content/drive/MyDrive')
notebooks = []
for dirpath, dirnames, filenames in os.walk(root):
    for fn in filenames:
        if fn.endswith('.ipynb'):
            p = Path(dirpath) / fn
            try:
                mtime = time.ctime(p.stat().st_mtime)
                size = p.stat().st_size
            except Exception:
                mtime = "n/a"; size = -1
            notebooks.append((str(p), size, mtime))

# 3) print results
if not notebooks:
    print("No .ipynb files found under /content/drive/MyDrive. Check other folders or move your file into MyDrive.")
else:
    print(f"Found {len(notebooks)} .ipynb files. Showing first 200 matches (if available):\n")
    for i, (path, size, mtime) in enumerate(notebooks[:200], 1):
        print(f"{i:3d}. {path} — {size} bytes — modified: {mtime}")

# 4) Choose which notebook to clean:
# By default this will clean the FIRST notebook found.
# If you want a different one, copy the exact path from the printed list and set TARGET_PATH below.
if notebooks:
    TARGET_PATH = notebooks[0][0]   # <<-- change this to an exact string if you prefer another file
    print("\nDefault target to clean (first match):", TARGET_PATH)

    # 5) Load and clean notebook (remove widgets, outputs, normalize)
    nb = nbformat.read(TARGET_PATH, as_version=4)
    changed = False
    if 'widgets' in nb.metadata:
        del nb.metadata['widgets']; changed = True
    nb.metadata.setdefault('kernelspec', nb.metadata.get('kernelspec', {}))
    nb.nbformat = 4
    nb.nbformat_minor = max(0, int(getattr(nb, 'nbformat_minor', 5)))
    for cell in nb.cells:
        if 'widgets' in cell.get('metadata', {}):
            del cell['metadata']['widgets']; changed = True
        if 'application/vnd.jupyter.widget-state+json' in cell.get('metadata', {}):
            cell['metadata'].pop('application/vnd.jupyter.widget-state+json', None); changed = True
        if 'outputs' in cell and cell['outputs']:
            cell['outputs'] = []; changed = True
        if 'execution_count' in cell and cell['execution_count'] is not None:
            cell['execution_count'] = None; changed = True

    clean_path = Path(TARGET_PATH).with_name(Path(TARGET_PATH).stem + '_clean.ipynb')
    nbformat.write(nb, str(clean_path))
    print("\nSaved cleaned notebook to:", clean_path)
    print("Changed metadata/outputs?:", changed)
    print("\nIf you want a different notebook cleaned, set TARGET_PATH to one of the printed paths and rerun the cell.")
# Out:
# Mounted at /content/drive
# Found 82 .ipynb files. Showing first 200 matches (if available):
#
#   1. /content/drive/MyDrive/Colab Notebooks/Kriti.ipynb — 28839 bytes — modified: Wed Jun  7 08:58:38 2023
#   2. /content/drive/MyDrive/Colab Notebooks/Copy of Kriti (1).ipynb — 28912 bytes — modified: Wed Jun  7 08:59:19 2023
#   3. /content/drive/MyDrive/Colab Notebooks/Copy of R Programming (1).ipynb — 1320152 bytes — modified: Fri Jun  9 11:40:21 2023
#   4. /content/drive/MyDrive/Colab Notebooks/Copy of topsis (1).ipynb — 13098 bytes — modified: Fri Jun  9 11:58:23 2023
#   5. /content/drive/MyDrive/Colab Notebooks/Python.ipynb — 85063 bytes — modified: Fri Jun  9 12:38:51 2023
#   6. /content/drive/MyDrive/Colab Notebooks/Object Oriented Programming .ipynb — 38719 bytes — modified: Wed Jun 21 10:28:14 2023
#   7. /content/drive/MyDrive/Colab Notebooks/Working with Pandas.ipynb — 359068 bytes — modified: Wed Jun 21 10:37:08 2023
#   8. /content/drive/MyDrive/Colab Notebooks/Copy of Working_with_Pandas (1).ipynb — 358549 bytes — modified: Wed Jun 21 10:40:11 2023
#   9. /content/drive/MyDrive/Colab Notebooks/Copy of Working_with_Pandas.ipynb — 358431 bytes — modified: Wed Jun 21 10:42:22 2023
#  10. /content/drive/MyDrive/Colab Notebooks/Data_Visualization_using_seaborn.ipynb — 1459692 bytes — modified: Fri Jun 23 04:51:31 2023
#  11. /content/drive/MyDrive/Colab Notebooks/Copy of Kriti.ipynb — 23616 bytes — modified: Fri Jun 23 05:04:26 2023
#  12. /content/drive/MyDrive/Colab Notebooks/assignment2.ipynb — 1500 bytes — modified: Fri Jun 23 05:04:38 2023
#  13. /content/drive/MyDrive/Colab Notebooks/miniproj1.ipynb — 10077 bytes — modified: Fri Jun 23 05:13:34 2023
#  14. /content/drive/MyDrive/Colab Notebooks/PythonEDA.ipynb — 409295 bytes — modified: Fri Jun 23 07:55:24 2023
#  15. /content/drive/MyDrive/Colab Notebooks/Copy of R Programming.ipynb — 1318922 bytes — modified: Sat Jun 24 07:05:45 2023
#  16. /content/drive/MyDrive/Colab Notebooks/Copy of topsis.ipynb — 14019 bytes — modified: Sat Jun 24 07:06:54 2023
#  17. /content/drive/MyDrive/Colab Notebooks/CNN2.ipynb — 10603 bytes — modified: Sun May  5 06:58:45 2024
#  18. /content/drive/MyDrive/Colab Notebooks/salesforce.ipynb — 2362 bytes — modified: Sun May  5 15:16:00 2024
#  19. /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb — 11031 bytes — modified: Mon Jun  3 05:46:02 2024
#  20. /content/drive/MyDrive/Colab Notebooks/image_classification.ipynb — 53166 bytes — modified: Fri Jun  7 15:30:12 2024
#  21. /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb — 13768 bytes — modified: Sat Jun  8 08:24:15 2024
#  22. /content/drive/MyDrive/Colab Notebooks/Number_Plate_Recognition.ipynb — 9658 bytes — modified: Mon Jun 10 14:47:41 2024
#  23. /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb — 3723 bytes — modified: Mon Jun 10 14:53:04 2024
#  24. /content/drive/MyDrive/Colab Notebooks/Untitled3.ipynb — 14998 bytes — modified: Mon Jun 10 15:00:58 2024
#  25. /content/drive/MyDrive/Colab Notebooks/Untitled4.ipynb — 1319 bytes — modified: Thu Jun 13 10:59:09 2024
#  26. /content/drive/MyDrive/Colab Notebooks/Number.ipynb — 1159149 bytes — modified: Sat Jun 15 09:47:08 2024
#  27. /content/drive/MyDrive/Colab Notebooks/snake_water_gun.ipynb — 3692 bytes — modified: Thu Jun 20 14:28:06 2024
#  28. /content/drive/MyDrive/Colab Notebooks/Untitled5.ipynb — 730190 bytes — modified: Fri Jun 21 15:12:42 2024
#  29. /content/drive/MyDrive/Colab Notebooks/chatbot.ipynb — 6327 bytes — modified: Sat Jun 22 14:34:37 2024
#  30. /content/drive/MyDrive/Colab Notebooks/perfect_guess.ipynb — 1176 bytes — modified: Tue Jun 25 12:54:50 2024
#  31. /content/drive/MyDrive/Colab Notebooks/2048.ipynb — 17372 bytes — modified: Thu Jul  4 10:49:22 2024
#  32. /content/drive/MyDrive/Colab Notebooks/yolo.ipynb — 985095 bytes — modified: Tue Jul  9 15:25:30 2024
#  33. /content/drive/MyDrive/Colab Notebooks/dcode.ipynb — 419286 bytes — modified: Tue Jul  9 15:28:40 2024
#  34. /content/drive/MyDrive/Colab Notebooks/scode.ipynb — 15807 bytes — modified: Tue Jul  9 16:05:23 2024
#  35. /content/drive/MyDrive/Colab Notebooks/yes_no.ipynb — 1157 bytes — modified: Sun Jul 21 09:24:12 2024
#  36. /content/drive/MyDrive/Colab Notebooks/virtual_assistant.ipynb — 11125 bytes — modified: Tue Jul 23 18:49:02 2024
#  37. /content/drive/MyDrive/Colab Notebooks/Copy of Courses.ipynb — 52030 bytes — modified: Thu Jul 25 13:19:22 2024
#  38. /content/drive/MyDrive/Colab Notebooks/Compass.ipynb — 36043 bytes — modified: Wed Jul 31 18:53:07 2024
#  39. /content/drive/MyDrive/Colab Notebooks/Ranking.ipynb — 13861 bytes — modified: Thu Aug  1 15:59:32 2024
#  40. /content/drive/MyDrive/Colab Notebooks/edge01.ipynb — 3641 bytes — modified: Tue Aug  6 04:56:58 2024
#  41. /content/drive/MyDrive/Colab Notebooks/Meesho.ipynb — 16385 bytes — modified: Fri Sep 13 13:29:18 2024
#  42. /content/drive/MyDrive/Colab Notebooks/Untitled6.ipynb — 3397 bytes — modified: Thu Sep 19 17:25:33 2024
#  43. /content/drive/MyDrive/Colab Notebooks/Untitled7.ipynb — 10053 bytes — modified: Fri Oct  4 03:05:27 2024
#  44. /content/drive/MyDrive/Colab Notebooks/Untitled8.ipynb — 19249 bytes — modified: Sun Oct 13 12:16:39 2024
#  45. /content/drive/MyDrive/Colab Notebooks/Number_Plate.ipynb — 5556319 bytes — modified: Mon Oct 14 16:06:25 2024
#  46. /content/drive/MyDrive/Colab Notebooks/Untitled9.ipynb — 20180 bytes — modified: Mon Oct 14 18:03:32 2024
#  47. /content/drive/MyDrive/Colab Notebooks/amex.ipynb — 6994 bytes — modified: Fri Nov  8 10:27:22 2024
#  48. /content/drive/MyDrive/Colab Notebooks/Personalized Quiz Generator.ipynb — 23583 bytes — modified: Sat Nov  9 05:17:11 2024
#  49. /content/drive/MyDrive/Colab Notebooks/Untitled10.ipynb — 12205 bytes — modified: Mon Nov 11 12:22:38 2024
#  50. /content/drive/MyDrive/Colab Notebooks/Untitled11.ipynb — 324 bytes — modified: Thu Nov 14 13:18:39 2024
#  51. /content/drive/MyDrive/Colab Notebooks/sudoku.ipynb — 4436 bytes — modified: Thu Nov 21 08:08:56 2024
#  52. /content/drive/MyDrive/Colab Notebooks/Untitled12.ipynb — 4850 bytes — modified: Sun Jan 12 09:23:24 2025
#  53. /content/drive/MyDrive/Colab Notebooks/embedded_vision.ipynb — 10675 bytes — modified: Mon Jan 27 05:26:04 2025
#  54. /content/drive/MyDrive/Colab Notebooks/sumo_code1.ipynb — 53230 bytes — modified: Thu Jan 30 03:49:13 2025
#  55. /content/drive/MyDrive/Colab Notebooks/sumo_code2.ipynb — 44543 bytes — modified: Thu Jan 30 04:09:35 2025
#  56. /content/drive/MyDrive/Colab Notebooks/sumo_code3.ipynb — 42820 bytes — modified: Thu Jan 30 04:53:42 2025
#  57. /content/drive/MyDrive/Colab Notebooks/sumo_code4.ipynb — 29382 bytes — modified: Thu Jan 30 04:58:32 2025
#  58. /content/drive/MyDrive/Colab Notebooks/sumo_code6.ipynb — 7256 bytes — modified: Fri Jan 31 12:08:25 2025
#  59. /content/drive/MyDrive/Colab Notebooks/sumo_code7.ipynb — 5190 bytes — modified: Fri Jan 31 12:17:25 2025
#  60. /content/drive/MyDrive/Colab Notebooks/sumo_code9.ipynb — 1186 bytes — modified: Fri Jan 31 12:18:06 2025
#  61. /content/drive/MyDrive/Colab Notebooks/sumo_code10.ipynb — 34777 bytes — modified: Sun Feb  2 19:38:55 2025
#  62. /content/drive/MyDrive/Colab Notebooks/sumo_code11.ipynb — 5473 bytes — modified: Wed Feb  5 09:32:30 2025
#  63. /content/drive/MyDrive/Colab Notebooks/sumo_code12.ipynb — 390465 bytes — modified: Sat Feb  8 17:56:01 2025
#  64. /content/drive/MyDrive/Colab Notebooks/sumo_code13.ipynb — 18331 bytes — modified: Mon Feb 10 09:47:36 2025
#  65. /content/drive/MyDrive/Colab Notebooks/maddpg (1).ipynb — 18382 bytes — modified: Mon Feb 17 16:47:22 2025
#  66. /content/drive/MyDrive/Colab Notebooks/ppo.ipynb — 24120 bytes — modified: Mon Feb 17 16:54:10 2025
#  67. /content/drive/MyDrive/Colab Notebooks/lstm.ipynb — 49875 bytes — modified: Mon Feb 17 17:08:59 2025
#  68. /content/drive/MyDrive/Colab Notebooks/triton.ipynb — 4648 bytes — modified: Sun Mar  2 10:40:48 2025
#  69. /content/drive/MyDrive/Colab Notebooks/inference.ipynb — 1185 bytes — modified: Tue Mar  4 11:31:44 2025
#  70. /content/drive/MyDrive/Colab Notebooks/maddpg.ipynb — 5432 bytes — modified: Fri Mar 28 16:58:00 2025
#  71. /content/drive/MyDrive/Colab Notebooks/combo.ipynb — 3143 bytes — modified: Fri Mar 28 18:05:58 2025
#  72. /content/drive/MyDrive/Colab Notebooks/capstone1.ipynb — 20580 bytes — modified: Sat Mar 29 10:56:42 2025
#  73. /content/drive/MyDrive/Colab Notebooks/Untitled13.ipynb — 6844 bytes — modified: Sat Mar 29 11:25:04 2025
#  74. /content/drive/MyDrive/Colab Notebooks/unnn.ipynb — 324 bytes — modified: Sun May  4 10:34:46 2025
#  75. /content/drive/MyDrive/Colab Notebooks/Untitled14.ipynb — 10738 bytes — modified: Sun May  4 10:39:41 2025
#  76. /content/drive/MyDrive/Colab Notebooks/DCV_project.ipynb — 324 bytes — modified: Sun May  4 16:19:15 2025
#  77. /content/drive/MyDrive/Colab Notebooks/DCV11.ipynb — 12880 bytes — modified: Mon May 12 08:12:30 2025
#  78. /content/drive/MyDrive/Colab Notebooks/DCV12.ipynb — 425417 bytes — modified: Mon May 12 12:23:29 2025
#  79. /content/drive/MyDrive/Colab Notebooks/Untitled15.ipynb — 471015 bytes — modified: Fri Nov  7 18:16:56 2025
#  80. /content/drive/MyDrive/Colab Notebooks/DP_RL_Lab_Assignment.ipynb — 193058 bytes — modified: Mon Nov 17 10:37:04 2025
#  81. /content/drive/MyDrive/Colab Notebooks/assignment789.ipynb — 109270 bytes — modified: Mon Nov 17 11:07:58 2025
#  82. /content/drive/MyDrive/Colab Notebooks/RL_Project.ipynb — 170678 bytes — modified: Mon Nov 17 13:02:24 2025
#
# Default target to clean (first match): /content/drive/MyDrive/Colab Notebooks/Kriti.ipynb
#
# Saved cleaned notebook to: /content/drive/MyDrive/Colab Notebooks/Kriti_clean.ipynb
# Changed metadata/outputs?: True
#
# If you want a different notebook cleaned, set TARGET_PATH to one of the printed paths and rerun the cell.

# %%
# (Optional) Install packages if running in Colab
# Uncomment to run in Colab if packages missing.
# !pip install --quiet yfinance pandas numpy matplotlib ipywidgets ta stable-baselines3==2.0.0

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import ipywidgets as widgets
# %matplotlib inline

# %%
def download_data(ticker, start='2018-01-01', end='2024-12-31'):
    df = yf.download(ticker, start=start, end=end, progress=False)
    if isinstance(df.columns, pd.MultiIndex):
        try:
            lvl0 = list(df.columns.get_level_values(0))
            lvl1 = list(df.columns.get_level_values(1))
            if len(set(lvl1)) == 1:
                df.columns = lvl0
        except Exception:
            df.columns = [c[0] if isinstance(c, tuple) else c for c in df.columns]
    df = df.dropna()
    return df

def add_basic_indicators(df):
    df = df.copy()
    df['return_1'] = df['Close'].pct_change()
    df['sma_5'] = df['Close'].rolling(5).mean()
    df['sma_20'] = df['Close'].rolling(20).mean()
    df = df.dropna().reset_index()
    return df

ticker = 'AAPL'
df_raw = download_data(ticker, start='2018-01-01', end='2024-12-31')
df = add_basic_indicators(df_raw)
print('Loaded', ticker, 'shape:', df.shape)
df.head()
# Out:
# Loaded AAPL shape: (1741, 9)
# /tmp/ipython-input-2371377968.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end, progress=False)
#         Date      Close       High        Low       Open     Volume  return_1  \
# 0 2018-01-30  39.103012  39.196687  38.571396  38.765775  184192800 -0.005894
# 1 2018-01-31  39.210732  39.447268  38.992935  39.079585  129915600  0.002755
# 2 2018-02-01  39.292713  39.489433  39.053836  39.149856  188923200  0.002091
# 3 2018-02-02  37.587784  39.063193  37.494109  38.875839  346375200 -0.043390
# 4 2018-02-05  36.648689  38.379367  36.533934  37.259930  290954000 -0.024984
#
#        sma_5     sma_20
# 0  39.895522  40.827603
# 1  39.577486  40.771045
# 2  39.421514  40.718938
# 3  38.905822  40.572216
# 4  38.368586  40.355472

# %%
class ManualTrader:
    def __init__(self, df, initial_cash=10000, transaction_cost_pct=0.001):
        self.df = df.reset_index(drop=True)
        self.initial_cash = initial_cash
        self.transaction_cost_pct = transaction_cost_pct
        self.reset()
        self.btn_buy = widgets.Button(description='Buy', button_style='success')
        self.btn_hold = widgets.Button(description='Hold')
        self.btn_sell = widgets.Button(description='Sell', button_style='danger')
        self.btn_next = widgets.Button(description='Auto-advance 10 steps', button_style='info')
        self.out = widgets.Output(layout={'border': '1px solid black'})
        self.btn_buy.on_click(self.on_buy)
        self.btn_hold.on_click(self.on_hold)
        self.btn_sell.on_click(self.on_sell)
        self.btn_next.on_click(self.on_advance10)
        self.controls = widgets.HBox([self.btn_buy, self.btn_hold, self.btn_sell, self.btn_next])
        display(self.controls, self.out)
        self.render()

    def reset(self):
        self.current_step = 0 + 30
        self.cash = float(self.initial_cash)
        self.position = 0
        self.position_price = 0.0
        self.portfolio_history = []
        self.trade_log = []

    def get_price(self, step=None):
        if step is None:
            step = self.current_step
        return float(self.df.loc[step, 'Close'])

    def portfolio_value(self):
        return self.cash + self.position * self.get_price()

    def step_action(self, action):
        price = self.get_price()
        prev_value = self.portfolio_value()
        if action == 'buy' and self.position == 0:
            cost = price * (1 + self.transaction_cost_pct)
            if self.cash >= cost:
                self.cash -= cost
                self.position = 1
                self.position_price = price
                self.trade_log.append({'step': self.current_step, 'action': 'buy', 'price': price})
        elif action == 'sell' and self.position == 1:
            proceeds = price * (1 - self.transaction_cost_pct)
            self.cash += proceeds
            self.position = 0
            self.trade_log.append({'step': self.current_step, 'action': 'sell', 'price': price})
        self.current_step += 1
        value = self.portfolio_value()
        self.portfolio_history.append(value)
        return value - prev_value

    def on_buy(self, _):
        self._handle_action('buy')

    def on_hold(self, _):
        self._handle_action('hold')

    def on_sell(self, _):
        self._handle_action('sell')

    def on_advance10(self, _):
        for _ in range(10):
            if self.current_step >= len(self.df)-1:
                break
            self._handle_action('hold')

    def _handle_action(self, action):
        if self.current_step >= len(self.df)-1:
            with self.out:
                print('End of data reached. Resetting...')
            return
        reward = self.step_action(action)
        self.render(action, reward)

    def render(self, last_action=None, reward=0.0):
        with self.out:
            clear_output(wait=True)
            step = self.current_step
            price = self.get_price(step-1)
            fig, ax = plt.subplots(2,1, figsize=(10,6), gridspec_kw={'height_ratios':[2,1]})
            ax[0].plot(self.df['Date'][:step], self.df['Close'][:step], label='Close')
            ax[0].plot(self.df['Date'][:step], self.df['sma_5'][:step], label='SMA5', alpha=0.7)
            ax[0].plot(self.df['Date'][:step], self.df['sma_20'][:step], label='SMA20', alpha=0.7)
            ax[0].legend(loc='upper left')
            ax[0].set_title(f'Time {step-1} | Price: {price:.2f} | Last action: {last_action} | Reward: {reward:.2f}')
            if len(self.portfolio_history)>0:
                ax[1].plot(self.portfolio_history, label='Portfolio Value')
            ax[1].axhline(self.initial_cash, color='gray', linestyle='--', label='Initial Cash')
            ax[1].legend(loc='upper left')
            plt.tight_layout()
            display(fig)
            print(f"Step: {step-1}  |  Price: {price:.2f}  |  Cash: {self.cash:.2f}  |  Position: {self.position}  |  Portfolio: {self.portfolio_value():.2f}")
            print('Recent trades (last 10):')
            for t in self.trade_log[-10:]:
                print(t)
            plt.close(fig)

trader = ManualTrader(df=df, initial_cash=10000)
# Out:
# HBox(children=(Button(button_style='success', description='Buy', style=ButtonStyle()), Button(description='Hol…
# Output(layout=Layout(border='1px solid black'))

# %%
try:
    from stable_baselines3 import PPO
    from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
    import gym
    class SimpleGymEnv(gym.Env):
        def __init__(self, df, window_size=30, initial_cash=10000, transaction_cost_pct=0.001):
            super().__init__()
            self.df = df.reset_index(drop=True)
            self.window_size = window_size
            self.transaction_cost_pct = transaction_cost_pct
            self.initial_cash = initial_cash
            self.feature_cols = ['Close']
            obs_dim = window_size * len(self.feature_cols) + 3
            self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(obs_dim,), dtype=np.float32)
            self.action_space = gym.spaces.Discrete(3)
            self.reset()
        def _get_obs(self):
            start = self.current_step - self.window_size + 1
            window = self.df.loc[start:self.current_step, self.feature_cols].values
            flat = window.flatten()
            cash_norm = np.array([self.cash / self.initial_cash], dtype=np.float32)
            position = np.array([self.position], dtype=np.float32)
            position_price_norm = np.array([0.0], dtype=np.float32)
            if self.position == 1:
                position_price_norm = np.array([self.position_price / self.initial_cash], dtype=np.float32)
            return np.concatenate([flat, cash_norm, position, position_price_norm]).astype(np.float32)
        def reset(self):
            self.current_step = self.window_size - 1
            self.cash = self.initial_cash
            self.position = 0
            self.position_price = 0.0
            self.total_trades = 0
            return self._get_obs()
        def step(self, action):
            price = float(self.df.loc[self.current_step,'Close'])
            prev_portfolio = self.cash + self.position*price
            if action==1 and self.position==0:
                cost = price*(1+self.transaction_cost_pct)
                if self.cash>=cost:
                    self.cash-=cost; self.position=1; self.position_price=price
            elif action==2 and self.position==1:
                proceeds=price*(1-self.transaction_cost_pct)
                self.cash+=proceeds; self.position=0; self.position_price=0.0
            self.current_step+=1
            done = self.current_step>=len(self.df)-1
            current_price = float(self.df.loc[self.current_step,'Close']) if not done else price
            portfolio = self.cash + self.position*current_price
            reward = portfolio - prev_portfolio
            obs = self._get_obs() if not done else np.zeros(self.observation_space.shape)
            info = {'portfolio_value': portfolio}
            return obs, float(reward), done, info

    train_env = DummyVecEnv([lambda: SimpleGymEnv(df=df, window_size=30)])
    train_env = VecNormalize(train_env, norm_obs=True, norm_reward=False, clip_obs=10.)
    model = PPO('MlpPolicy', train_env, verbose=1)
    TOTAL = 10000
    model.learn(total_timesteps=TOTAL)
    model.save('/content/ppo_trader_demo')
    print('Saved model to /content/ppo_trader_demo')
except Exception as e:
    print('Skipping PPO demo (missing packages or runtime issue):', e)
# Out:
# Skipping PPO demo (missing packages or runtime issue): Missing shimmy installation. You an OpenAI Gym environment. Stable-Baselines3 (SB3) has transitioned to using Gymnasium internally. In order to use OpenAI Gym environments with SB3, you need to install shimmy (`pip install 'shimmy>=0.2.1'`).
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# !pip install stable-baselines3==2.0.0 gym==0.26.2
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Collecting stable-baselines3==2.0.0
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting gym==0.26.2
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 12.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gymnasium==0.28.1 (from stable-baselines3==2.0.0)
#   Downloading gymnasium-0.28.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0) (2.0.2)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0) (2.8.0+cu126)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0) (3.10.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym==0.26.2) (0.1.0)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable-baselines3==2.0.0)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.0.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11->stable-baselines3==2.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0) (3.0.3)
# Downloading stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 kB 12.9 MB/s eta 0:00:00
# Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 46.6 MB/s eta 0:00:00
# Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827727 sha256=1617a7c95e5355fc120ea58694d6ffe89f4406b67d68bdc1bd4b5c3a1aa11942
#   Stored in directory: /root/.cache/pip/wheels/95/51/6c/9bb05ebbe7c5cb8171dfaa3611f32622ca4658d53f31c79077
# Successfully built gym
# Installing collected packages: jax-jumpy, gym, gymnasium, stable-baselines3
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.2.2
#     Uninstalling gymnasium-1.2.2:
#       Successfully uninstalled gymnasium-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.28.1 which is incompatible.
# Successfully installed gym-0.26.2 gymnasium-0.28.1 jax-jumpy-1.0.0 stable-baselines3-2.0.0
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
